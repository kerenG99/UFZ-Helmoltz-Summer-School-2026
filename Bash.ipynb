# %% [markdown]
# <a href="https://colab.research.google.com/github/kerenG99/UFZ-Helmoltz-Summer-School-2026/blob/main/Bash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Unix, Bash & Git: Tools for Reproducible Science
#
# ## Bash Notebook
#
# *This Jupyter Notebook was developed for the Summer School on Trends in Multi-Omics Data Analysis for Microbial Ecology and Biotechnology (2026) to be presented on 16.07.2026.*
#
# *For any questions regarding the material provided here, please contact:*
#
# *Breno L. S. de Almeida: brenoslivio@usp.br*
#
# ---

# %% [markdown]
# ### Table of contents
#
# - [A note on running this notebook](#note)
# - [1. Setting up a practice sandbox](#sec1)
# - [2. Example commands](#sec2)
#     - [2.1 Navigating the filesystem](#sec2-1)
#     - [2.2 Getting help & system info](#sec2-2)
#     - [2.3 Creating & removing directories and files](#sec2-3)
#     - [2.4 Viewing file content](#sec2-4)
#     - [2.5 Searching: find & grep](#sec2-5)
#     - [2.6 Copying, moving, hiding & removing files](#sec2-6)
#     - [2.7 Disk usage](#sec2-7)
#     - [2.8 Permissions](#sec2-8)
#     - [2.9 Pipes & redirection](#sec2-9)
#     - [2.10 Shell scripts](#sec2-10)
# - [3. Capstone practice project](#sec3)

# %% [markdown]
# <a name="note"></a>
#
# ### A note on running this notebook
#
# Most commands below are safe to run directly in a code cell. A few classic
# Linux tools, however, are **interactive, full-screen programs** built for a
# real terminal, and they will not behave properly inside a notebook cell:
#
# - `nano` (text editor)
# - `htop` (process viewer)
# - `less` / `more` (pagers)
# - `man` (manual pages, opens a pager)
#
# Whenever these come up, the notebook will show you what they do and ask you
# to **try them in a separate terminal window** instead. Everywhere else
# we'll use notebook-friendly equivalents (`touch`, `echo`, `cat`, `head`,
# `wc`, `--help`) so the whole notebook can be run top to bottom.
#
# However, as we will see, Google Colab uses a Ubuntu virtual machine so we can use Jupyter Notebooks in it.

# %%
# !apt update
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [100 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://cli.github.com/packages stable/main amd64 Packages [355 B]
# Get:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [10.5 MB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,615 kB]
# Get:14 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.6 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,426 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [7,619 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.6 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [82.8 kB]
# Get:19 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [4,091 kB]
# Get:20 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [3,110 kB]
# Get:21 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [7,332 kB]
# Get:22 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,313 kB]
# Fetched 40.7 MB in 8s (5,423 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 101 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
# !apt install neofetch
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   caca-utils chafa fonts-droid-fallback fonts-noto-mono fonts-urw-base35
#   ghostscript gsfonts imagemagick imagemagick-6-common imagemagick-6.q16 jp2a
#   libchafa0 libdjvulibre-text libdjvulibre21 libfftw3-double3 libgc1 libgs9
#   libgs9-common libid3tag0 libidn12 libijs-0.35 libilmbase25 libimlib2
#   libjbig2dec0 libjxr-tools libjxr0 liblqr-1-0 libmagickcore-6.q16-6
#   libmagickcore-6.q16-6-extra libmagickwand-6.q16-6 libnetpbm10 libopenexr25
#   libpci3 libsixel-bin libsixel1 libwmflite-0.2-7 netpbm pci.ids pciutils
#   poppler-data toilet toilet-fonts w3m w3m-img
# Suggested packages:
#   fonts-noto fonts-freefont-otf | fonts-freefont-ttf fonts-texgyre
#   ghostscript-x imagemagick-doc autotrace cups-bsd | lpr | lprng enscript gimp
#   gnuplot grads hp2xx html2ps libwmf-bin mplayer povray radiance sane-utils
#   texlive-base-bin transfig ufraw-batch libfftw3-bin libfftw3-dev inkscape
#   poppler-utils fonts-japanese-mincho | fonts-ipafont-mincho
#   fonts-japanese-gothic | fonts-ipafont-gothic fonts-arphic-ukai
#   fonts-arphic-uming fonts-nanum figlet cmigemo dict dict-wn dictd w3m-el xsel
# The following NEW packages will be installed:
#   caca-utils chafa fonts-droid-fallback fonts-noto-mono fonts-urw-base35
#   ghostscript gsfonts imagemagick imagemagick-6-common imagemagick-6.q16 jp2a
#   libchafa0 libdjvulibre-text libdjvulibre21 libfftw3-double3 libgc1 libgs9
#   libgs9-common libid3tag0 libidn12 libijs-0.35 libilmbase25 libimlib2
#   libjbig2dec0 libjxr-tools libjxr0 liblqr-1-0 libmagickcore-6.q16-6
#   libmagickcore-6.q16-6-extra libmagickwand-6.q16-6 libnetpbm10 libopenexr25
#   libpci3 libsixel-bin libsixel1 libwmflite-0.2-7 neofetch netpbm pci.ids
#   pciutils poppler-data toilet toilet-fonts w3m w3m-img
# 0 upgraded, 45 newly installed, 0 to remove and 101 not upgraded.
# Need to get 29.0 MB of archives.
# After this operation, 100 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1build1 [1,805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-double3 amd64 3.3.8-2ubuntu8 [770 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblqr-1-0 amd64 0.4.2-2.1 [27.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 imagemagick-6-common all 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5 [64.3 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libmagickcore-6.q16-6 amd64 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5 [1,795 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libmagickwand-6.q16-6 amd64 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5 [328 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 poppler-data all 0.4.11-1 [2,171 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 pci.ids all 0.0~2022.01.22-1ubuntu0.1 [251 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpci3 amd64 1:3.7.0-6 [28.9 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 pciutils amd64 1:3.7.0-6 [63.6 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libid3tag0 amd64 0.15.1b-14 [31.3 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libimlib2 amd64 1.7.4-1build1 [195 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 caca-utils amd64 0.99.beta19-2.2ubuntu4.2 [57.2 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libchafa0 amd64 1.8.0-1 [88.3 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/universe amd64 chafa amd64 1.8.0-1 [38.6 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-mono all 20201225-1build1 [397 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-urw-base35 all 20200910-1 [6,367 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgs9-common all 9.55.0~dfsg1-0ubuntu5.13 [753 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libidn12 amd64 1.38-4ubuntu1.1 [60.5 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libijs-0.35 amd64 0.35-15build2 [16.5 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjbig2dec0 amd64 0.19-3build2 [64.7 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgs9 amd64 9.55.0~dfsg1-0ubuntu5.13 [5,032 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ghostscript amd64 9.55.0~dfsg1-0ubuntu5.13 [49.4 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/universe amd64 gsfonts all 1:8.11+urwcyr1.0.7~pre44-4.5 [3,120 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 imagemagick-6.q16 amd64 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5 [224 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 imagemagick amd64 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5 [14.6 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/universe amd64 jp2a amd64 1.1.1-1 [28.9 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdjvulibre-text all 3.5.28-2ubuntu0.22.04.2 [51.1 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdjvulibre21 amd64 3.5.28-2ubuntu0.22.04.2 [625 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgc1 amd64 1:8.0.6-1.1build1 [96.8 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libilmbase25 amd64 2.5.7-2 [175 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjxr0 amd64 1.2~git20170615.f752187-5 [174 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjxr-tools amd64 1.2~git20170615.f752187-5 [16.0 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenexr25 amd64 2.5.7-1 [780 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwmflite-0.2-7 amd64 0.2.12-5ubuntu1 [68.9 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libmagickcore-6.q16-6-extra amd64 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5 [70.1 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libnetpbm10 amd64 2:10.0-15.4 [59.1 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/universe amd64 neofetch all 7.1.0-3 [84.3 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/universe amd64 netpbm amd64 2:10.0-15.4 [1,007 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/universe amd64 toilet-fonts all 0.3-1.4 [714 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/universe amd64 toilet amd64 0.3-1.4 [12.7 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 w3m amd64 0.5.3+git20210102-6ubuntu0.2 [1,104 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 w3m-img amd64 0.5.3+git20210102-6ubuntu0.2 [23.6 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsixel1 amd64 1.10.3-3 [111 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsixel-bin amd64 1.10.3-3 [18.5 kB]
# Fetched 29.0 MB in 4s (8,283 kB/s)
# Extracting templates from packages: 100%
# Selecting previously unselected package fonts-droid-fallback.
# (Reading database ... 118243 files and directories currently installed.)
# Preparing to unpack .../00-fonts-droid-fallback_1%3a6.0.1r16-1.1build1_all.deb ...
# Unpacking fonts-droid-fallback (1:6.0.1r16-1.1build1) ...
# Selecting previously unselected package libfftw3-double3:amd64.
# Preparing to unpack .../01-libfftw3-double3_3.3.8-2ubuntu8_amd64.deb ...
# Unpacking libfftw3-double3:amd64 (3.3.8-2ubuntu8) ...
# Selecting previously unselected package liblqr-1-0:amd64.
# Preparing to unpack .../02-liblqr-1-0_0.4.2-2.1_amd64.deb ...
# Unpacking liblqr-1-0:amd64 (0.4.2-2.1) ...
# Selecting previously unselected package imagemagick-6-common.
# Preparing to unpack .../03-imagemagick-6-common_8%3a6.9.11.60+dfsg-1.3ubuntu0.22.04.5_all.deb ...
# Unpacking imagemagick-6-common (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5) ...
# Selecting previously unselected package libmagickcore-6.q16-6:amd64.
# Preparing to unpack .../04-libmagickcore-6.q16-6_8%3a6.9.11.60+dfsg-1.3ubuntu0.22.04.5_amd64.deb ...
# Unpacking libmagickcore-6.q16-6:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5) ...
# Selecting previously unselected package libmagickwand-6.q16-6:amd64.
# Preparing to unpack .../05-libmagickwand-6.q16-6_8%3a6.9.11.60+dfsg-1.3ubuntu0.22.04.5_amd64.deb ...
# Unpacking libmagickwand-6.q16-6:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../06-poppler-data_0.4.11-1_all.deb ...
# Unpacking poppler-data (0.4.11-1) ...
# Selecting previously unselected package pci.ids.
# Preparing to unpack .../07-pci.ids_0.0~2022.01.22-1ubuntu0.1_all.deb ...
# Unpacking pci.ids (0.0~2022.01.22-1ubuntu0.1) ...
# Selecting previously unselected package libpci3:amd64.
# Preparing to unpack .../08-libpci3_1%3a3.7.0-6_amd64.deb ...
# Unpacking libpci3:amd64 (1:3.7.0-6) ...
# Selecting previously unselected package pciutils.
# Preparing to unpack .../09-pciutils_1%3a3.7.0-6_amd64.deb ...
# Unpacking pciutils (1:3.7.0-6) ...
# Selecting previously unselected package libid3tag0:amd64.
# Preparing to unpack .../10-libid3tag0_0.15.1b-14_amd64.deb ...
# Unpacking libid3tag0:amd64 (0.15.1b-14) ...
# Selecting previously unselected package libimlib2:amd64.
# Preparing to unpack .../11-libimlib2_1.7.4-1build1_amd64.deb ...
# Unpacking libimlib2:amd64 (1.7.4-1build1) ...
# Selecting previously unselected package caca-utils.
# Preparing to unpack .../12-caca-utils_0.99.beta19-2.2ubuntu4.2_amd64.deb ...
# Unpacking caca-utils (0.99.beta19-2.2ubuntu4.2) ...
# Selecting previously unselected package libchafa0:amd64.
# Preparing to unpack .../13-libchafa0_1.8.0-1_amd64.deb ...
# Unpacking libchafa0:amd64 (1.8.0-1) ...
# Selecting previously unselected package chafa.
# Preparing to unpack .../14-chafa_1.8.0-1_amd64.deb ...
# Unpacking chafa (1.8.0-1) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../15-fonts-noto-mono_20201225-1build1_all.deb ...
# Unpacking fonts-noto-mono (20201225-1build1) ...
# Selecting previously unselected package fonts-urw-base35.
# Preparing to unpack .../16-fonts-urw-base35_20200910-1_all.deb ...
# Unpacking fonts-urw-base35 (20200910-1) ...
# Selecting previously unselected package libgs9-common.
# Preparing to unpack .../17-libgs9-common_9.55.0~dfsg1-0ubuntu5.13_all.deb ...
# Unpacking libgs9-common (9.55.0~dfsg1-0ubuntu5.13) ...
# Selecting previously unselected package libidn12:amd64.
# Preparing to unpack .../18-libidn12_1.38-4ubuntu1.1_amd64.deb ...
# Unpacking libidn12:amd64 (1.38-4ubuntu1.1) ...
# Selecting previously unselected package libijs-0.35:amd64.
# Preparing to unpack .../19-libijs-0.35_0.35-15build2_amd64.deb ...
# Unpacking libijs-0.35:amd64 (0.35-15build2) ...
# Selecting previously unselected package libjbig2dec0:amd64.
# Preparing to unpack .../20-libjbig2dec0_0.19-3build2_amd64.deb ...
# Unpacking libjbig2dec0:amd64 (0.19-3build2) ...
# Selecting previously unselected package libgs9:amd64.
# Preparing to unpack .../21-libgs9_9.55.0~dfsg1-0ubuntu5.13_amd64.deb ...
# Unpacking libgs9:amd64 (9.55.0~dfsg1-0ubuntu5.13) ...
# Selecting previously unselected package ghostscript.
# Preparing to unpack .../22-ghostscript_9.55.0~dfsg1-0ubuntu5.13_amd64.deb ...
# Unpacking ghostscript (9.55.0~dfsg1-0ubuntu5.13) ...
# Selecting previously unselected package gsfonts.
# Preparing to unpack .../23-gsfonts_1%3a8.11+urwcyr1.0.7~pre44-4.5_all.deb ...
# Unpacking gsfonts (1:8.11+urwcyr1.0.7~pre44-4.5) ...
# Selecting previously unselected package imagemagick-6.q16.
# Preparing to unpack .../24-imagemagick-6.q16_8%3a6.9.11.60+dfsg-1.3ubuntu0.22.04.5_amd64.deb ...
# Unpacking imagemagick-6.q16 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5) ...
# Selecting previously unselected package imagemagick.
# Preparing to unpack .../25-imagemagick_8%3a6.9.11.60+dfsg-1.3ubuntu0.22.04.5_amd64.deb ...
# Unpacking imagemagick (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5) ...
# Selecting previously unselected package jp2a.
# Preparing to unpack .../26-jp2a_1.1.1-1_amd64.deb ...
# Unpacking jp2a (1.1.1-1) ...
# Selecting previously unselected package libdjvulibre-text.
# Preparing to unpack .../27-libdjvulibre-text_3.5.28-2ubuntu0.22.04.2_all.deb ...
# Unpacking libdjvulibre-text (3.5.28-2ubuntu0.22.04.2) ...
# Selecting previously unselected package libdjvulibre21:amd64.
# Preparing to unpack .../28-libdjvulibre21_3.5.28-2ubuntu0.22.04.2_amd64.deb ...
# Unpacking libdjvulibre21:amd64 (3.5.28-2ubuntu0.22.04.2) ...
# Selecting previously unselected package libgc1:amd64.
# Preparing to unpack .../29-libgc1_1%3a8.0.6-1.1build1_amd64.deb ...
# Unpacking libgc1:amd64 (1:8.0.6-1.1build1) ...
# Selecting previously unselected package libilmbase25:amd64.
# Preparing to unpack .../30-libilmbase25_2.5.7-2_amd64.deb ...
# Unpacking libilmbase25:amd64 (2.5.7-2) ...
# Selecting previously unselected package libjxr0:amd64.
# Preparing to unpack .../31-libjxr0_1.2~git20170615.f752187-5_amd64.deb ...
# Unpacking libjxr0:amd64 (1.2~git20170615.f752187-5) ...
# Selecting previously unselected package libjxr-tools.
# Preparing to unpack .../32-libjxr-tools_1.2~git20170615.f752187-5_amd64.deb ...
# Unpacking libjxr-tools (1.2~git20170615.f752187-5) ...
# Selecting previously unselected package libopenexr25:amd64.
# Preparing to unpack .../33-libopenexr25_2.5.7-1_amd64.deb ...
# Unpacking libopenexr25:amd64 (2.5.7-1) ...
# Selecting previously unselected package libwmflite-0.2-7:amd64.
# Preparing to unpack .../34-libwmflite-0.2-7_0.2.12-5ubuntu1_amd64.deb ...
# Unpacking libwmflite-0.2-7:amd64 (0.2.12-5ubuntu1) ...
# Selecting previously unselected package libmagickcore-6.q16-6-extra:amd64.
# Preparing to unpack .../35-libmagickcore-6.q16-6-extra_8%3a6.9.11.60+dfsg-1.3ubuntu0.22.04.5_amd64.deb ...
# Unpacking libmagickcore-6.q16-6-extra:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5) ...
# Selecting previously unselected package libnetpbm10.
# Preparing to unpack .../36-libnetpbm10_2%3a10.0-15.4_amd64.deb ...
# Unpacking libnetpbm10 (2:10.0-15.4) ...
# Selecting previously unselected package neofetch.
# Preparing to unpack .../37-neofetch_7.1.0-3_all.deb ...
# Unpacking neofetch (7.1.0-3) ...
# Selecting previously unselected package netpbm.
# Preparing to unpack .../38-netpbm_2%3a10.0-15.4_amd64.deb ...
# Unpacking netpbm (2:10.0-15.4) ...
# Selecting previously unselected package toilet-fonts.
# Preparing to unpack .../39-toilet-fonts_0.3-1.4_all.deb ...
# Unpacking toilet-fonts (0.3-1.4) ...
# Selecting previously unselected package toilet.
# Preparing to unpack .../40-toilet_0.3-1.4_amd64.deb ...
# Unpacking toilet (0.3-1.4) ...
# Selecting previously unselected package w3m.
# Preparing to unpack .../41-w3m_0.5.3+git20210102-6ubuntu0.2_amd64.deb ...
# Unpacking w3m (0.5.3+git20210102-6ubuntu0.2) ...
# Selecting previously unselected package w3m-img.
# Preparing to unpack .../42-w3m-img_0.5.3+git20210102-6ubuntu0.2_amd64.deb ...
# Unpacking w3m-img (0.5.3+git20210102-6ubuntu0.2) ...
# Selecting previously unselected package libsixel1:amd64.
# Preparing to unpack .../43-libsixel1_1.10.3-3_amd64.deb ...
# Unpacking libsixel1:amd64 (1.10.3-3) ...
# Selecting previously unselected package libsixel-bin.
# Preparing to unpack .../44-libsixel-bin_1.10.3-3_amd64.deb ...
# Unpacking libsixel-bin (1.10.3-3) ...
# Setting up imagemagick-6-common (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5) ...
# Setting up pci.ids (0.0~2022.01.22-1ubuntu0.1) ...
# Setting up toilet-fonts (0.3-1.4) ...
# Setting up fonts-noto-mono (20201225-1build1) ...
# Setting up libwmflite-0.2-7:amd64 (0.2.12-5ubuntu1) ...
# Setting up toilet (0.3-1.4) ...
# update-alternatives: using /usr/bin/figlet-toilet to provide /usr/bin/figlet (figlet) in auto mode
# Setting up libijs-0.35:amd64 (0.35-15build2) ...
# Setting up libjxr0:amd64 (1.2~git20170615.f752187-5) ...
# Setting up jp2a (1.1.1-1) ...
# Setting up libilmbase25:amd64 (2.5.7-2) ...
# Setting up libnetpbm10 (2:10.0-15.4) ...
# Setting up fonts-urw-base35 (20200910-1) ...
# Setting up neofetch (7.1.0-3) ...
# Setting up poppler-data (0.4.11-1) ...
# Setting up libchafa0:amd64 (1.8.0-1) ...
# Setting up libopenexr25:amd64 (2.5.7-1) ...
# Setting up libid3tag0:amd64 (0.15.1b-14) ...
# Setting up libjbig2dec0:amd64 (0.19-3build2) ...
# Setting up gsfonts (1:8.11+urwcyr1.0.7~pre44-4.5) ...
# Setting up libsixel1:amd64 (1.10.3-3) ...
# Setting up libidn12:amd64 (1.38-4ubuntu1.1) ...
# Setting up libimlib2:amd64 (1.7.4-1build1) ...
# Setting up netpbm (2:10.0-15.4) ...
# Setting up libgc1:amd64 (1:8.0.6-1.1build1) ...
# Setting up libfftw3-double3:amd64 (3.3.8-2ubuntu8) ...
# Setting up libpci3:amd64 (1:3.7.0-6) ...
# Setting up liblqr-1-0:amd64 (0.4.2-2.1) ...
# Setting up fonts-droid-fallback (1:6.0.1r16-1.1build1) ...
# Setting up libdjvulibre-text (3.5.28-2ubuntu0.22.04.2) ...
# Setting up libgs9-common (9.55.0~dfsg1-0ubuntu5.13) ...
# Setting up libjxr-tools (1.2~git20170615.f752187-5) ...
# Setting up libgs9:amd64 (9.55.0~dfsg1-0ubuntu5.13) ...
# Setting up caca-utils (0.99.beta19-2.2ubuntu4.2) ...
# Setting up libdjvulibre21:amd64 (3.5.28-2ubuntu0.22.04.2) ...
# Setting up ghostscript (9.55.0~dfsg1-0ubuntu5.13) ...
# Setting up libsixel-bin (1.10.3-3) ...
# Setting up libmagickcore-6.q16-6:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5) ...
# Setting up w3m (0.5.3+git20210102-6ubuntu0.2) ...
# Setting up pciutils (1:3.7.0-6) ...
# Setting up w3m-img (0.5.3+git20210102-6ubuntu0.2) ...
# Setting up libmagickwand-6.q16-6:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5) ...
# Setting up libmagickcore-6.q16-6-extra:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5) ...
# Setting up chafa (1.8.0-1) ...
# Setting up imagemagick-6.q16 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5) ...
# update-alternatives: using /usr/bin/compare-im6.q16 to provide /usr/bin/compare (compare) in auto mode
# update-alternatives: using /usr/bin/compare-im6.q16 to provide /usr/bin/compare-im6 (compare-im6) in auto mode
# update-alternatives: using /usr/bin/animate-im6.q16 to provide /usr/bin/animate (animate) in auto mode
# update-alternatives: using /usr/bin/animate-im6.q16 to provide /usr/bin/animate-im6 (animate-im6) in auto mode
# update-alternatives: using /usr/bin/convert-im6.q16 to provide /usr/bin/convert (convert) in auto mode
# update-alternatives: using /usr/bin/convert-im6.q16 to provide /usr/bin/convert-im6 (convert-im6) in auto mode
# update-alternatives: using /usr/bin/composite-im6.q16 to provide /usr/bin/composite (composite) in auto mode
# update-alternatives: using /usr/bin/composite-im6.q16 to provide /usr/bin/composite-im6 (composite-im6) in auto mode
# update-alternatives: using /usr/bin/conjure-im6.q16 to provide /usr/bin/conjure (conjure) in auto mode
# update-alternatives: using /usr/bin/conjure-im6.q16 to provide /usr/bin/conjure-im6 (conjure-im6) in auto mode
# update-alternatives: using /usr/bin/import-im6.q16 to provide /usr/bin/import (import) in auto mode
# update-alternatives: using /usr/bin/import-im6.q16 to provide /usr/bin/import-im6 (import-im6) in auto mode
# update-alternatives: using /usr/bin/identify-im6.q16 to provide /usr/bin/identify (identify) in auto mode
# update-alternatives: using /usr/bin/identify-im6.q16 to provide /usr/bin/identify-im6 (identify-im6) in auto mode
# update-alternatives: using /usr/bin/stream-im6.q16 to provide /usr/bin/stream (stream) in auto mode
# update-alternatives: using /usr/bin/stream-im6.q16 to provide /usr/bin/stream-im6 (stream-im6) in auto mode
# update-alternatives: using /usr/bin/display-im6.q16 to provide /usr/bin/display (display) in auto mode
# update-alternatives: using /usr/bin/display-im6.q16 to provide /usr/bin/display-im6 (display-im6) in auto mode
# update-alternatives: using /usr/bin/montage-im6.q16 to provide /usr/bin/montage (montage) in auto mode
# update-alternatives: using /usr/bin/montage-im6.q16 to provide /usr/bin/montage-im6 (montage-im6) in auto mode
# update-alternatives: using /usr/bin/mogrify-im6.q16 to provide /usr/bin/mogrify (mogrify) in auto mode
# update-alternatives: using /usr/bin/mogrify-im6.q16 to provide /usr/bin/mogrify-im6 (mogrify-im6) in auto mode
# Setting up imagemagick (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.13) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...

# %%
# !neofetch
# Out:
#             .-/+oossssoo+/-.
#         `:+ssssssssssssssssss+:`
#       -+ssssssssssssssssssyyssss+-
#     .ossssssssssssssssssdMMMNysssso.
#    /ssssssssssshdmmNNmmyNMMMMhssssss/
#   +ssssssssshmydMMMMMMMNddddyssssssss+
#  /sssssssshNMMMyhhyyyyhmNMMMNhssssssss/
# .ssssssssdMMMNhsssssssssshNMMMdssssssss.
# +sssshhhyNMMNyssssssssssssyNMMMysssssss+
# ossyNMMMNyMMhsssssssssssssshmmmhssssssso
# ossyNMMMNyMMhsssssssssssssshmmmhssssssso
# +sssshhhyNMMNyssssssssssssyNMMMysssssss+
# .ssssssssdMMMNhsssssssssshNMMMdssssssss.
#  /sssssssshNMMMyhhyyyyhdNMMMNhssssssss/
#   +sssssssssdmydMMMMMMMMddddyssssssss+
#    /ssssssssssshdmNNNNmyNMMMMhssssss/
#     .ossssssssssssssssssdMMMNysssso.
#       -+sssssssssssssssssyyyssss+-
#         `:+ssssssssssssssssss+:`
#             .-/+oossssoo+/-.
# root@84348fe4787a
# -----------------
# OS: Ubuntu 22.04.5 LTS x86_64
# Host: Google Compute Engine
# Kernel: 6.6.122+
# Uptime: 11 mins
# Packages: 1123 (dpkg)
# Shell: bash 5.1.16
# Terminal: jupyter-server
# CPU: Intel Xeon (2) @ 2.199GHz
# Memory: 797MiB / 12975MiB

# %% [markdown]
# <a name="sec1"></a>
#
# ### 1. Setting up a practice sandbox
#
# To practice safely (including destructive commands like `rm -r`), let's
# work inside a dedicated playground directory instead of anywhere important.
# Run this once at the start of the session:

# %%
# %%bash
#
# mkdir -p ~/bash_practice
# cd ~/bash_practice
# pwd
# Out:
# /root/bash_practice

# %% [markdown]
# Every exercise from here on assumes you are inside `~/bash_practice`
# (or a subfolder of it). If a code cell ever complains that a file or
# folder doesn't exist, `cd ~/bash_practice` first and check with `pwd`.

# %% [markdown]
# <a name="sec2"></a>
#
# ### 2. Example commands
#
# Here you can find some basic commands for interacting with a Linux OS.
# Don't copy all the commands at once — go through them one by one, run the
# demo, then do the exercise yourself before checking the solution.

# %% [markdown]
# <a name="sec2-1"></a>
#
# #### 2.1 Navigating the filesystem
#
# - `pwd` — show current directory
# - `cd <path>` — change directory (`~` = home, `..` = one level up, `../..` = two levels up, ...)
# - `ls` — list directory contents
#     - `-a` → also show hidden files
#     - `-l` → show permissions and details
#     - `-r` → reverse order

# %%
# %%bash
#
# pwd
# cd ~
# ls -l
# cd ~/bash_practice
# pwd

# %% [markdown]
# **📝 Exercise 2.1** — Imagine you just received sequencing data for a new
# project called `project_alpha`.
#
# 1. From `~/bash_practice`, create a directory called `project_alpha`.
# 2. Move into it and confirm your current path with `pwd`.
# 3. Go back up one level, then list the contents of `~/bash_practice`,
#    including hidden files.

# %%
# Write your answer here

# %% [markdown]
# <a name="sec2-2"></a>
#
# #### 2.2 Getting help & system info
#
# - `man <command>` — full manual page (**interactive pager — use a terminal**)
# - `htop` — live view of running processes (**interactive — use a terminal**)
# - `date` — display date and time
# - `free -m` / `free -h` — free and used memory (`-h` = human-readable)
# - `<command> --help` — quick, non-interactive summary of a command's options
#   (a good notebook-friendly substitute for `man`)

# %%
# %%bash
#
# date
# free -m
# ls --help | head -10

# %% [markdown]
# **📝 Exercise 2.2**
#
# 1. In a real terminal (not this notebook), run `man du` and find out what
#    the `-h` flag does. Quit the pager with `q`.
# 2. In this notebook, check how much free memory your system currently has,
#    in human-readable format.

# %%
# Write your answer here

# %% [markdown]
# <a name="sec2-3"></a>
#
# #### 2.3 Creating & removing directories and files
#
# - `mkdir <name>` — create a directory
# - `rmdir <name>` — remove an **empty** directory
# - `rm -r <name>` — remove a directory and everything inside it (careful!)
# - `mv <old> <new>` — move or rename a file/directory
# - `nano <file>` — create/edit a text file interactively (**use a terminal**)
# - `touch <file>` — quickly create an empty file (notebook-friendly)

# %%
# %%bash
#
# cd ~/bash_practice
# mkdir test_dir
# rmdir test_dir
# mkdir demo_dir
# mv demo_dir renamed_dir
# rm -r renamed_dir
# touch scratch_file.txt
# ls

# %% [markdown]
# **📝 Exercise 2.3** — Inside `project_alpha`:
#
# 1. Create three subdirectories: `raw_data`, `scripts`, `results`.
# 2. Rename `results` to `results_2026`.
# 3. Create an empty file called `notes.txt` inside `raw_data`.
# 4. We decide we don't need `scripts` yet — remove it.

# %%
# Write your answer here

# %% [markdown]
# <a name="sec2-4"></a>
#
# #### 2.4 Viewing file content
#
# - `cat <file>` — print the whole file to standard output
# - `head -N <file>` / `tail -N <file>` — first / last N lines (default 20 if N omitted)
# - `less` / `more` — scroll through output a page at a time (**interactive — use a terminal**)
# - `wc <file>` — count lines, words, characters, bytes
#     - `-l` lines, `-w` words, `-m` characters, `-c` bytes, `-L` longest line

# %%
# %%bash
#
# echo "First line" > scratch_file.txt
# echo "Second line" >> scratch_file.txt
# cat scratch_file.txt
# head -1 scratch_file.txt
# tail -1 scratch_file.txt
# wc scratch_file.txt

# %% [markdown]
# **📝 Exercise 2.4**
#
# 1. Append three lines to `raw_data/notes.txt`, each describing a sample,
#    e.g. `Sample S1: 32.5 ng/uL` (use `echo "..." >> raw_data/notes.txt`).
# 2. Count how many lines, words and characters are in the file.
# 3. Show only the first 2 lines, then only the last line, of the file.

# %%
# Write your answer here

# %% [markdown]
# <a name="sec2-5"></a>
#
# #### 2.5 Searching: find & grep
#
# - `find <location> <type_of_search> <pattern>` — search for files
#     - e.g. `find . -type f -iname "*ple_fi*.*"` — search here, files only,
#       ignore case, name contains `ple_fi`
# - `grep "<pattern>" <file>` — search for text inside a file
#     - `grep -r "<pattern>" <dir>` — search recursively through a directory
#     - `grep -l "<pattern>" <dir>` — only print the names of matching files

# %%
# %%bash
#
# cd ~/bash_practice/project_alpha
# find . -iname "*note*"
# grep "S2" raw_data/notes.txt

# %% [markdown]
# **📝 Exercise 2.5**
#
# 1. Create two more files in `raw_data`: `sample_S4.txt` containing the line
#    `status: passed`, and `sample_S5.txt` containing the line `status: failed`.
# 2. Use `find` to list every `.txt` file anywhere under `project_alpha`.
# 3. Use `grep` to find every file that contains the word `failed`.
# 4. Combine `find` and `wc` to count how many `.txt` files exist in total.

# %%
# Write your answer here

# %% [markdown]
# <a name="sec2-6"></a>
#
# #### 2.6 Copying, moving, hiding & removing files
#
# - `cp <source> <target>` — creates a copy of a file
# - `mv <old_name> <new_name>` — renaming a file starting with `.` hides it
#   from a plain `ls` (still visible with `ls -a`)
# - `rm <file>` — remove a file

# %%
# %%bash
#
# cd ~/bash_practice
# cp scratch_file.txt scratch_copy.txt
# mv scratch_copy.txt .scratch_copy.txt
# ls
# ls -a
# rm .scratch_copy.txt

# %% [markdown]
# **📝 Exercise 2.6**
#
# 1. Make a backup copy of `raw_data/notes.txt` called `notes_backup.txt`.
# 2. "Hide" the backup by renaming it to start with a dot.
# 3. Confirm it's hidden with a plain `ls`, then reveal it with `ls -a`.
# 4. Remove the hidden backup.

# %%
# Write your answer here

# %% [markdown]
# <a name="sec2-7"></a>
#
# #### 2.7 Disk usage
#
# - `du` — display information about disk usage
#     - `-s` → summary (total only)
#     - `-h` → human-readable sizes
#     - `-sh` → summary in human-readable form
# - `df -h` — free and used space on the system's partitions

# %%
# %%bash
#
# du -sh ~/bash_practice
# df -h | head -5

# %% [markdown]
# **📝 Exercise 2.7**
#
# 1. Check the total size of `project_alpha` in human-readable form.
# 2. Check the disk usage of each subdirectory inside `project_alpha`
#    (one summary line per subdirectory).
# 3. Check the free/used space on the whole system's partitions.

# %%
# Write your answer here

# %% [markdown]
# <a name="sec2-8"></a>
#
# #### 2.8 Permissions
#
# ![Figure 2 - Permission explanations](https://www.digitalocean.com/api/static-content/v1/images?src=https%3A%2F%2Fassets.digitalocean.com%2Farticles%2Flinux_basics%2Fmode.png&token=11cf955620aa854e140ef39a8fe4056cb8ad4c95e06e23949bbd449e098c20ad)
#
# Source:
# https://www.digitalocean.com/community/tutorials/an-introduction-to-linux-permissions
#
# Reading the string from `ls -l` left to right: the first character is the
# file type (`-` file, `d` directory), then three groups of `rwx` for
# **owner**, **group**, and **others**.
#
# - `-rw-------`: only the owner can read/write it
# - `-rwxr-xr-x`: executable by every user on the system ("world-executable")
# - `-rw-rw-rw-`: modifiable by every user on the system ("world-writable")
# - `drwxr-xr-x`: a directory every user can read and access
# - `drwxrwx---`: a directory modifiable (including contents) by owner and group
# - `drwxr-x---`: a directory accessible by its group
#
# To **change** permissions, use `chmod`:
#
# - `chmod a-w <file>` — remove write permission for everyone (`a`)
# - `chmod u+w <file>` — add write permission back for the owner (`u`)
# - `chmod 444 <file>` — numeric form: read-only for owner/group/others

# %%
# %%bash
#
# cd ~/bash_practice
# ls -l scratch_file.txt
# chmod a-w scratch_file.txt
# ls -l scratch_file.txt
# chmod u+w scratch_file.txt
# ls -l scratch_file.txt

# %% [markdown]
# **📝 Exercise 2.8**
#
# 1. Check the current permissions of `raw_data/notes.txt` with `ls -l`.
# 2. Make it read-only for everyone.
# 3. Try to append text to it with `echo "test" >> raw_data/notes.txt` —
#    what happens?
# 4. Restore write permission for yourself (the owner).
#
# > **Note:** if you're running this notebook as the `root` user (common in
# > containers/cloud environments), root can bypass file permissions, so
# > step 3 may succeed even after removing write access. Try this exercise
# > logged in as a regular (non-root) user to see the "Permission denied"
# > error in full effect.

# %%
# Write your answer here

# %% [markdown]
# <a name="sec2-9"></a>
#
# #### 2.9 Pipes & redirection
#
# You can combine commands using the pipe symbol `|`, feeding the output of
# one command as input to the next. `>` writes/overwrites a file with the
# output, `>>` appends to it.
#
# Some commands can also act *directly* on each result they find (`-exec`),
# or hand results to another command as arguments (`xargs`):
#
# - `find <location> ... -exec <command> {} +` — runs `<command>` on the
#   files `find` matched. `{}` is a placeholder that gets replaced by the
#   matched path(s); the trailing `+` batches as many paths as possible into
#   a single call to `<command>` (use `\;` instead of `+` to run the command
#   once *per file* — slower, but occasionally necessary). E.g.
#   `find . -name "*.txt" -exec realpath {} +` prints the **absolute path**
#   of every `.txt` file found.
# - `<command> | xargs <other_command>` — takes whatever `<command>` printed
#   (one item per line) and feeds it to `<other_command>` as **arguments**,
#   rather than as piped-in text. This matters because some commands (like
#   `grep`) expect filenames as arguments, not text on standard input —
#   `find . -name "*.txt" | xargs grep -l "failed"` runs `grep -l "failed"`
#   directly on the list of `.txt` files that `find` located.

# %%
# %%bash
#
# cd ~/bash_practice/project_alpha
# find . -name "*.txt" | wc -l # number of files ending with .txt
# find . -name "*.txt" | grep "sample" | wc -l # number of .txt files with "sample" in the name
# find . -name "*.txt" -exec realpath {} + >> realpaths_to_file.txt # write out absolute paths, one per line
# cat raw_data/notes.txt | head -2
# cat raw_data/notes.txt | wc -l

# %% [markdown]
# **📝 Exercise 2.9**
#
# 1. Count how many sample files report `status: passed` across all of
#    `raw_data` (hint: `grep -r` + `wc -l`).
# 2. Combine `find` and `grep -l` to count how many `.txt` files contain the
#    word `failed`, without opening them manually.
# 3. Save the list of absolute paths of all `.txt` files under
#    `project_alpha` into a new file called `file_report.txt`.

# %%
# Write your answer here

# %% [markdown]
# <a name="sec2-10"></a>
#
# #### 2.10 Shell scripts
#
# A **shell script** is just a text file full of Bash commands, saved so you
# can run the whole sequence as one program instead of retyping every line.
# This is exactly what the capstone project below asks you to build.
#
# - `#!/bin/bash` — the **shebang**, always the very first line of a script;
#   it tells the system which interpreter should execute the file.
# - `chmod +x <script>` — makes the file executable (see **2.8** above).
# - `./<script>` — runs it. The `./` means "look in the current directory";
#   without it, Bash searches your `$PATH` and likely won't find the script.
# - `variable=value` (no spaces around `=`!), then `$variable` or
#   `${variable}` — store a value and reuse it later in the script.
# - `` $(command) `` — **command substitution**: runs `command` and drops its
#   output in place, e.g. `count=$(find . -name "*.txt" | wc -l)` stores the
#   number of `.txt` files found in the variable `count`.
#
# **Creating the script file**
#
# - In a real terminal you'd normally open a text editor, e.g. `nano script.sh`,
#   type the commands, then save and exit.
# - `nano` doesn't work inside a notebook cell (it's interactive), so here we
#   write the whole file in one go with a **heredoc**:
#   ```bash
#   cat > script.sh << 'EOF'
#   #!/bin/bash
#   echo "Hello, world!"
#   EOF
#   ```
#   Everything between `<< 'EOF'` and the closing `EOF` is written to
#   `script.sh` exactly as typed.
# - Since Google Colab runs on a real Ubuntu VM, you can also create or edit
#   the file **by hand**: click the folder icon in the left sidebar to open
#   the file browser, navigate to the right folder, right-click → *New
#   file*, then double-click it to open Colab's built-in text editor. Just
#   make sure you save it to the same path your notebook is using (e.g.
#   inside `~/bash_practice`).

# %%
# %%bash
#
# cd ~/bash_practice
# cat > greet.sh << 'EOF'
# #!/bin/bash
# name="World"
# echo "Hello, $name!"
# lines=$(wc -l < greet.sh)
# echo "This script itself has $lines lines."
# EOF
# chmod +x greet.sh
# ./greet.sh
# rm greet.sh

# %% [markdown]
# **📝 Exercise 2.10**
#
# 1. Inside `~/bash_practice`, write a script called `count_files.sh` that
#    counts how many files exist anywhere under `project_alpha` (use `find`
#    and `wc -l`), stores the count in a variable, and prints a sentence
#    like `There are 8 files in project_alpha.`
# 2. Make the script executable and run it.
# 3. Bonus: add a second line to the script that also prints how many of
#    those files are `.txt` files.

# %%
# Write your answer here

# %% [markdown]
# <a name="sec3"></a>
#
# ### 3. Capstone practice project
#
# Time to combine everything into one realistic mini-workflow. Scenario:
#
# > You are a bioinformatics trainee. You've been handed a folder of raw
# > sequencing sample files. Your job is to organize them, audit their QC
# > status, and produce a clean, protected summary report.
#
# Starting fresh, in `~/bash_practice`:
#
# 1. Create a new project folder called `capstone`, with subfolders `data`,
#    `scripts`, and `reports`.
# 2. Inside `data`, create 6 sample files named `sample_S1.txt` ... `sample_S6.txt`,
#    each containing a single line `status: passed` or `status: failed`
#    (mix them, e.g. 4 passed / 2 failed).
# 3. Count how many samples passed and how many failed QC, using `grep` and
#    `wc -l` (don't count them by hand!).
# 4. Write a small script `scripts/summary.sh` that prints the total number
#    of sample files, and the pass/fail counts (see **2.10** above for how
#    to create and run a shell script — `nano` in a real terminal, or
#    `cat > scripts/summary.sh << 'EOF' ... EOF` here in the notebook).
#    Make it executable with `chmod +x` and run it.
# 5. Redirect the script's output into `reports/summary.txt`, then make that
#    report **read-only** so nobody can accidentally edit it afterwards.
# 6. Once you're happy with the result, clean up by removing the entire
#    `capstone` directory — double-check you're inside `~/bash_practice`
#    and typing the right folder name before running `rm -r`!

# %%
# Write your answer here
